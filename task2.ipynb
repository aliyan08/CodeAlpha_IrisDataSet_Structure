# %%
from sklearn.datasets import load_iris

data = load_iris()
X = data.data
y = data.target

# %%
import pandas as pd
df = pd.DataFrame(X, columns=data.feature_names)
df['target'] = y

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# visualize the data
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, hue='target')
plt.show()

# %%
# apply K-means and visualize the result
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
df['cluster'] = kmeans.labels_
sns.pairplot(df, hue='cluster')
plt.show()

# %%
# 3D visualization
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['sepal length (cm)'], df['sepal width (cm)'], df['petal length (cm)'], c=df['cluster'], cmap='rainbow')
ax.set_xlabel('sepal length (cm)')
ax.set_ylabel('sepal width (cm)')
ax.set_zlabel('petal length (cm)')
plt.show()

# %%
# scatter plot
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(df['sepal length (cm)'], df['sepal width (cm)'], df['petal length (cm)'], c=df['target'], cmap='rainbow')
ax.set_xlabel('sepal length (cm)')
ax.set_ylabel('sepal width (cm)')
plt.show()
